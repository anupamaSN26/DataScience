# %% [markdown]
# Aim: Program to implement Decision Tree classification using any standard dataset (IRIS) available in the public domain and find the accuracy of the algorithm

# %% [markdown]
# Use Iris dataset to implement decision tree algorithm

# %%
# Import the necessary libraries

from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# %%
# Load a dataset -Iris dataset

iris=datasets.load_iris()
x=iris.data
y=iris.target

# %%
# Split the dataset into a training set and a testing set(trainig 70% records)

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=1)

# %%
# Create a Decision Tree Classifier

DT_clf=DecisionTreeClassifier(random_state=1)

# %%
# Train the classifier on the training data

DT_clf.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(random_state=1)

# %%
# Make predictions on the test data

y_pred=DT_clf.predict(x_test)

# Calculate accuracy and confusion matrix
accuracy=accuracy_score(y_test,y_pred)
cm=confusion_matrix(y_test,y_pred)
cf=classification_report(y_test,y_pred)
print("Accuracy score: ",accuracy)
print("Confusion matrix : \n",cm)
print("Classification report: \n",cf)
# Out:
# Accuracy score:  0.9555555555555556
# Confusion matrix :
#  [[14  0  0]
#  [ 0 17  1]
#  [ 0  1 12]]
# Classification report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        14
#            1       0.94      0.94      0.94        18
#            2       0.92      0.92      0.92        13
#
#     accuracy                           0.96        45
#    macro avg       0.96      0.96      0.96        45
# weighted avg       0.96      0.96      0.96        45

# %%
#Plot decision tree
#import matplotlib.pyplot as plt
#from sklearn.tree import plot_tree
#plot_tree(model variable name)
#plt.show()

import matplotlib.pyplot as plt
from sklearn.tree import plot_tree
plt.figure(figsize=(15,10))
plot_tree(DT_clf,feature_names=iris.feature_names,class_names=iris.target_names)
plt.show()

# %%
_ # Create model with Entropy as atribute selection method
DT_clf1=DecisionTreeClassifier(criterion="entropy",random_state=1)
DT_clf1.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=1)

# %%
y_pred=DT_clf1.predict(x_test)


# Calculate accuracy and confusion matrix
accuracy=accuracy_score(y_test,y_pred)
cm=confusion_matrix(y_test,y_pred)
cf=classification_report(y_test,y_pred)
print("Accuracy score: ",accuracy)
print("Confusion matrix : \n",cm)
print("Classification report: \n",cf)
# Out:
# Accuracy score:  0.9555555555555556
# Confusion matrix :
#  [[14  0  0]
#  [ 0 17  1]
#  [ 0  1 12]]
# Classification report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        14
#            1       0.94      0.94      0.94        18
#            2       0.92      0.92      0.92        13
#
#     accuracy                           0.96        45
#    macro avg       0.96      0.96      0.96        45
# weighted avg       0.96      0.96      0.96        45

# %%
#Plot decision tree
#import matplotlib.pyplot as plt
#from sklearn.tree import plot_tree
#plot_tree(model variable name)
#plt.show()

import matplotlib.pyplot as plt
from sklearn.tree import plot_tree
plt.figure(figsize=(15,10))
plot_tree(DT_clf1,feature_names=iris.feature_names,class_names=iris.target_names)
plt.show()
